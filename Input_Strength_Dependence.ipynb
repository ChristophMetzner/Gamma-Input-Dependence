# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load data

# %%
drive_frequencies = [40.0, 30.0, 20.0]

s = 2**13
time = 500  # simulation time (in ms)
dt = float(time)/float(s)
time_points = np.linspace(0,time,int(time/dt)) 


freqs = np.load('Exploration/freqs.npy')

# Control
meg_d01_ctrl = np.zeros((3, 8192))
meg_d02_ctrl = np.zeros((3, 8192))
meg_d0225_ctrl = np.zeros((3, 8192))
meg_d025_ctrl = np.zeros((3, 8192))
meg_d0275_ctrl = np.zeros((3, 8192))
meg_d03_ctrl = np.zeros((3, 8192))
meg_d0325_ctrl = np.zeros((3, 8192))
meg_d035_ctrl = np.zeros((3, 8192))
meg_d0375_ctrl = np.zeros((3, 8192))
meg_d04_ctrl = np.zeros((3, 8192))
meg_d05_ctrl = np.zeros((3, 8192))

psd_d01_ctrl = np.zeros((3, 4095))
psd_d02_ctrl = np.zeros((3, 4095))
psd_d0225_ctrl = np.zeros((3, 4095))
psd_d025_ctrl = np.zeros((3, 4095))
psd_d0275_ctrl = np.zeros((3, 4095))
psd_d03_ctrl = np.zeros((3, 4095))
psd_d0325_ctrl = np.zeros((3, 4095))
psd_d035_ctrl = np.zeros((3, 4095))
psd_d0375_ctrl = np.zeros((3, 4095))
psd_d04_ctrl = np.zeros((3, 4095))
psd_d05_ctrl = np.zeros((3, 4095))

for i, f in enumerate(drive_frequencies):
    meg_d01_ctrl[i] = np.load('Exploration/Input_Strength_01/drive_01_control_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d02_ctrl[i] = np.load('Exploration/Input_Strength_02/drive_02_control_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0225_ctrl[i] = np.load('Exploration/Input_Strength_0225/drive_0225_control_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d025_ctrl[i] = np.load('Exploration/Input_Strength_025/drive_025_control_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0275_ctrl[i] = np.load('Exploration/Input_Strength_0275/drive_0275_control_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0325_ctrl[i] = np.load('Exploration/Input_Strength_0325/drive_0325_control_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d035_ctrl[i] = np.load('Exploration/Input_Strength_035/drive_035_control_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0375_ctrl[i] = np.load('Exploration/Input_Strength_0375/drive_0375_control_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d03_ctrl[i] = np.load('Exploration/Input_Strength_03/drive_03_control_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d04_ctrl[i] = np.load('Exploration/Input_Strength_04/drive_04_control_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d05_ctrl[i] = np.load('Exploration/Input_Strength_05/drive_05_control_drive_frequency_'+str(f)+'-MEG.npy')

    psd_d01_ctrl[i] = np.load('Exploration/Input_Strength_01/drive_01_control_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d02_ctrl[i] = np.load('Exploration/Input_Strength_02/drive_02_control_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0225_ctrl[i] = np.load('Exploration/Input_Strength_0225/drive_0225_control_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d025_ctrl[i] = np.load('Exploration/Input_Strength_025/drive_025_control_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0275_ctrl[i] = np.load('Exploration/Input_Strength_0275/drive_0275_control_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d03_ctrl[i] = np.load('Exploration/Input_Strength_03/drive_03_control_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0325_ctrl[i] = np.load('Exploration/Input_Strength_0325/drive_0325_control_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d035_ctrl[i] = np.load('Exploration/Input_Strength_035/drive_035_control_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0375_ctrl[i] = np.load('Exploration/Input_Strength_0375/drive_0375_control_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d04_ctrl[i] = np.load('Exploration/Input_Strength_04/drive_04_control_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d05_ctrl[i] = np.load('Exploration/Input_Strength_05/drive_05_control_drive_frequency_'+str(f)+'-PSD.npy')
    
    

# Tau inh
meg_d01_tau = np.zeros((3, 8192))
meg_d02_tau = np.zeros((3, 8192))
meg_d0225_tau = np.zeros((3, 8192))
meg_d025_tau = np.zeros((3, 8192))
meg_d0275_tau = np.zeros((3, 8192))
meg_d03_tau = np.zeros((3, 8192))
meg_d0325_tau = np.zeros((3, 8192))
meg_d035_tau = np.zeros((3, 8192))
meg_d0375_tau = np.zeros((3, 8192))
meg_d04_tau = np.zeros((3, 8192))
meg_d05_tau = np.zeros((3, 8192))

psd_d01_tau = np.zeros((3, 4095))
psd_d02_tau = np.zeros((3, 4095))
psd_d0225_tau = np.zeros((3, 4095))
psd_d025_tau = np.zeros((3, 4095))
psd_d0275_tau = np.zeros((3, 4095))
psd_d03_tau = np.zeros((3, 4095))
psd_d0325_tau = np.zeros((3, 4095))
psd_d035_tau = np.zeros((3, 4095))
psd_d0375_tau = np.zeros((3, 4095))
psd_d04_tau = np.zeros((3, 4095))
psd_d05_tau = np.zeros((3, 4095))

for i, f in enumerate(drive_frequencies):
    meg_d01_tau[i] = np.load('Exploration/Input_Strength_01/drive_01_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d02_tau[i] = np.load('Exploration/Input_Strength_02/drive_02_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0225_tau[i] = np.load('Exploration/Input_Strength_0225/drive_0225_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d025_tau[i] = np.load('Exploration/Input_Strength_025/drive_025_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0275_tau[i] = np.load('Exploration/Input_Strength_0275/drive_0275_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d03_tau[i] = np.load('Exploration/Input_Strength_03/drive_03_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0325_tau[i] = np.load('Exploration/Input_Strength_0325/drive_0325_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d035_tau[i] = np.load('Exploration/Input_Strength_035/drive_035_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0375_tau[i] = np.load('Exploration/Input_Strength_0375/drive_0375_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d04_tau[i] = np.load('Exploration/Input_Strength_04/drive_04_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d05_tau[i] = np.load('Exploration/Input_Strength_05/drive_05_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')

    psd_d01_tau[i] = np.load('Exploration/Input_Strength_01/drive_01_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d02_tau[i] = np.load('Exploration/Input_Strength_02/drive_02_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d02_tau[i] = np.load('Exploration/Input_Strength_02/drive_02_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d025_tau[i] = np.load('Exploration/Input_Strength_025/drive_025_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0275_tau[i] = np.load('Exploration/Input_Strength_0275/drive_0275_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d03_tau[i] = np.load('Exploration/Input_Strength_03/drive_03_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0325_tau[i] = np.load('Exploration/Input_Strength_0325/drive_0325_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d035_tau[i] = np.load('Exploration/Input_Strength_035/drive_035_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0375_tau[i] = np.load('Exploration/Input_Strength_0375/drive_0375_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d04_tau[i] = np.load('Exploration/Input_Strength_04/drive_04_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d05_tau[i] = np.load('Exploration/Input_Strength_05/drive_05_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    
# G inh
meg_d01_g = np.zeros((3, 8192))
meg_d02_g = np.zeros((3, 8192))
meg_d0225_g = np.zeros((3, 8192))
meg_d025_g = np.zeros((3, 8192))
meg_d0275_g = np.zeros((3, 8192))
meg_d03_g = np.zeros((3, 8192))
meg_d0325_g = np.zeros((3, 8192))
meg_d035_g = np.zeros((3, 8192))
meg_d0375_g = np.zeros((3, 8192))
meg_d04_g = np.zeros((3, 8192))
meg_d05_g = np.zeros((3, 8192))

psd_d01_g = np.zeros((3, 4095))
psd_d02_g = np.zeros((3, 4095))
psd_d0225_g = np.zeros((3, 4095))
psd_d025_g = np.zeros((3, 4095))
psd_d0275_g = np.zeros((3, 4095))
psd_d03_g = np.zeros((3, 4095))
psd_d0325_g = np.zeros((3, 4095))
psd_d035_g = np.zeros((3, 4095))
psd_d0375_g = np.zeros((3, 4095))
psd_d04_g = np.zeros((3, 4095))
psd_d05_g = np.zeros((3, 4095))

for i, f in enumerate(drive_frequencies):
    meg_d01_g[i] = np.load('Exploration/Input_Strength_01/drive_01_g_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d02_g[i] = np.load('Exploration/Input_Strength_02/drive_02_g_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0225_g[i] = np.load('Exploration/Input_Strength_0225/drive_0225_g_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d025_g[i] = np.load('Exploration/Input_Strength_025/drive_025_g_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0275_g[i] = np.load('Exploration/Input_Strength_0275/drive_0275_g_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d03_g[i] = np.load('Exploration/Input_Strength_03/drive_03_g_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0325_g[i] = np.load('Exploration/Input_Strength_0325/drive_0325_g_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d035_g[i] = np.load('Exploration/Input_Strength_035/drive_035_g_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0375_g[i] = np.load('Exploration/Input_Strength_0375/drive_0375_g_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d04_g[i] = np.load('Exploration/Input_Strength_04/drive_04_g_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d05_g[i] = np.load('Exploration/Input_Strength_05/drive_05_g_inh_drive_frequency_'+str(f)+'-MEG.npy')

    psd_d01_g[i] = np.load('Exploration/Input_Strength_01/drive_01_g_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d02_g[i] = np.load('Exploration/Input_Strength_02/drive_02_g_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0225_g[i] = np.load('Exploration/Input_Strength_0225/drive_0225_g_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d025_g[i] = np.load('Exploration/Input_Strength_025/drive_025_g_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0275_g[i] = np.load('Exploration/Input_Strength_0275/drive_0275_g_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d03_g[i] = np.load('Exploration/Input_Strength_03/drive_03_g_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0325_g[i] = np.load('Exploration/Input_Strength_0325/drive_0325_g_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d035_g[i] = np.load('Exploration/Input_Strength_035/drive_035_g_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0375_g[i] = np.load('Exploration/Input_Strength_0375/drive_0375_g_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d04_g[i] = np.load('Exploration/Input_Strength_04/drive_04_g_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d05_g[i] = np.load('Exploration/Input_Strength_05/drive_05_g_inh_drive_frequency_'+str(f)+'-PSD.npy')
    

# G and Tau inh
meg_d01_gtau = np.zeros((3, 8192))
meg_d02_gtau = np.zeros((3, 8192))
meg_d0225_gtau = np.zeros((3, 8192))
meg_d025_gtau = np.zeros((3, 8192))
meg_d0275_gtau = np.zeros((3, 8192))
meg_d03_gtau = np.zeros((3, 8192))
meg_d0325_gtau = np.zeros((3, 8192))
meg_d035_gtau = np.zeros((3, 8192))
meg_d0375_gtau = np.zeros((3, 8192))
meg_d04_gtau = np.zeros((3, 8192))
meg_d05_gtau = np.zeros((3, 8192))

psd_d01_gtau = np.zeros((3, 4095))
psd_d02_gtau = np.zeros((3, 4095))
psd_d0225_gtau = np.zeros((3, 4095))
psd_d025_gtau = np.zeros((3, 4095))
psd_d0275_gtau = np.zeros((3, 4095))
psd_d03_gtau = np.zeros((3, 4095))
psd_d0325_gtau = np.zeros((3, 4095))
psd_d035_gtau = np.zeros((3, 4095))
psd_d0375_gtau = np.zeros((3, 4095))
psd_d04_gtau = np.zeros((3, 4095))
psd_d05_gtau = np.zeros((3, 4095))

for i, f in enumerate(drive_frequencies):
    meg_d01_gtau[i] = np.load('Exploration/Input_Strength_01/drive_01_g_and_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d02_gtau[i] = np.load('Exploration/Input_Strength_02/drive_02_g_and_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0225_gtau[i] = np.load('Exploration/Input_Strength_0225/drive_0225_g_and_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d025_gtau[i] = np.load('Exploration/Input_Strength_025/drive_025_g_and_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0275_gtau[i] = np.load('Exploration/Input_Strength_0275/drive_0275_g_and_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d03_gtau[i] = np.load('Exploration/Input_Strength_03/drive_03_g_and_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0325_gtau[i] = np.load('Exploration/Input_Strength_0325/drive_0325_g_and_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d035_gtau[i] = np.load('Exploration/Input_Strength_035/drive_035_g_and_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d0375_gtau[i] = np.load('Exploration/Input_Strength_0375/drive_0375_g_and_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d04_gtau[i] = np.load('Exploration/Input_Strength_04/drive_04_g_and_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')
    meg_d05_gtau[i] = np.load('Exploration/Input_Strength_05/drive_05_g_and_tau_inh_drive_frequency_'+str(f)+'-MEG.npy')

    psd_d01_gtau[i] = np.load('Exploration/Input_Strength_01/drive_01_g_and_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d02_gtau[i] = np.load('Exploration/Input_Strength_02/drive_02_g_and_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0225_gtau[i] = np.load('Exploration/Input_Strength_0225/drive_0225_g_and_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d025_gtau[i] = np.load('Exploration/Input_Strength_025/drive_025_g_and_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0275_gtau[i] = np.load('Exploration/Input_Strength_0275/drive_0275_g_and_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d03_gtau[i] = np.load('Exploration/Input_Strength_03/drive_03_g_and_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0325_gtau[i] = np.load('Exploration/Input_Strength_0325/drive_0325_g_and_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d035_gtau[i] = np.load('Exploration/Input_Strength_035/drive_035_g_and_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d0375_gtau[i] = np.load('Exploration/Input_Strength_0375/drive_0375_g_and_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d04_gtau[i] = np.load('Exploration/Input_Strength_04/drive_04_g_and_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')
    psd_d05_gtau[i] = np.load('Exploration/Input_Strength_05/drive_05_g_and_tau_inh_drive_frequency_'+str(f)+'-PSD.npy')

# %% [markdown]
# ### MEG control

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_ctrl[0],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_ctrl[0],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_ctrl[0],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_ctrl[0],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_ctrl[0],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_ctrl[0],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_ctrl[0],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_ctrl[0],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_ctrl[0],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_ctrl[0],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_ctrl[0],str(colors[10]))

ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 40Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/Ctrl-40Hz-Drive-MEG.eps'
filenameeps = 'Figures/Ctrl-40Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_ctrl[1],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_ctrl[1],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_ctrl[1],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_ctrl[1],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_ctrl[1],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_ctrl[1],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_ctrl[1],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_ctrl[1],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_ctrl[1],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_ctrl[1],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_ctrl[1],str(colors[10]))


ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 30Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/Ctrl-30Hz-Drive-MEG.eps'
filenameeps = 'Figures/Ctrl-30Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_ctrl[2],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_ctrl[2],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_ctrl[2],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_ctrl[2],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_ctrl[2],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_ctrl[2],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_ctrl[2],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_ctrl[2],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_ctrl[2],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_ctrl[2],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_ctrl[2],str(colors[10]))

ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 20Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/Ctrl-20Hz-Drive-MEG.eps'
filenameeps = 'Figures/Ctrl-20Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### PSD Control

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_ctrl[0],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_ctrl[0],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_ctrl[0],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_ctrl[0],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_ctrl[0],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_ctrl[0],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_ctrl[0],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_ctrl[0],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_ctrl[0],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_ctrl[0],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_ctrl[0],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 40Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
ax.set_xlim([35., 45.0])


plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/Ctrl-40Hz-Drive-PSD.eps'
filenameeps = 'Figures/Ctrl-40Hz-Drive-PSD-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_ctrl[1],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_ctrl[1],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_ctrl[1],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_ctrl[1],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_ctrl[1],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_ctrl[1],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_ctrl[1],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_ctrl[1],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_ctrl[1],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_ctrl[1],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_ctrl[1],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 30Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
ax.set_xlim([25., 35.0])


plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/Ctrl-30Hz-Drive-PSD.eps'
filenameeps = 'Figures/Ctrl-30Hz-Drive-PSD-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_ctrl[2],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_ctrl[2],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_ctrl[2],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_ctrl[2],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_ctrl[2],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_ctrl[2],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_ctrl[2],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_ctrl[2],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_ctrl[2],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_ctrl[2],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_ctrl[2],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 20Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
#ax.set_xlim([15., 25.0])
ax.set_xlim([35., 45.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/Ctrl-20Hz-Drive-PSD.eps'
#filenameeps = 'Figures/Ctrl-20Hz-Drive-PSD-zoom20.eps'
filenameeps = 'Figures/Ctrl-20Hz-Drive-PSD-zoom40.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### Tau inh condition

# %% [markdown]
# ### MEG

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_tau[0],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_tau[0],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_tau[0],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_tau[0],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_tau[0],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_tau[0],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_tau[0],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_tau[0],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_tau[0],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_tau[0],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_tau[0],str(colors[10]))

ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence (Tau condition) - 40Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/Tau-40Hz-Drive-MEG.eps'
filenameeps = 'Figures/Tau-40Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_tau[1],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_tau[1],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_tau[1],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_tau[1],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_tau[1],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_tau[1],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_tau[1],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_tau[1],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_tau[1],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_tau[1],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_tau[1],str(colors[10]))

ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence (Tau condition) - 30Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/Tau-30Hz-Drive-MEG.eps'
filenameeps = 'Figures/Tau-30Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_tau[2],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_tau[2],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_tau[2],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_tau[2],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_tau[2],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_tau[2],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_tau[2],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_tau[2],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_tau[2],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_tau[2],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_tau[2],str(colors[10]))

ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence (Tau condition) - 20Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


filenameeps = 'Figures/Tau-20Hz-Drive-MEG.eps'
#filenameeps = 'Figures/Tau-20Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### PSD

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_tau[0],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_tau[0],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_tau[0],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_tau[0],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_tau[0],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_tau[0],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_tau[0],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_tau[0],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_tau[0],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_tau[0],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_tau[0],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 40Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
ax.set_xlim([35., 45.0])
#ax.set_xlim([15., 25.0])


#ax.set_ylim([0., 25.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/Tau-40Hz-Drive-PSD.eps'
filenameeps = 'Figures/Tau-40Hz-Drive-PSD-zoom40.eps'
#filenameeps = 'Figures/Tau-40Hz-Drive-PSD-zoom20.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_tau[1],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_tau[1],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_tau[1],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_tau[1],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_tau[1],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_tau[1],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_tau[1],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_tau[1],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_tau[1],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_tau[1],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_tau[1],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 30Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
ax.set_xlim([25., 35.0])


plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/Tau-30Hz-Drive-PSD.eps'
filenameeps = 'Figures/Tau-30Hz-Drive-PSD-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_tau[2],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_tau[2],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_tau[2],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_tau[2],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_tau[2],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_tau[2],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_tau[2],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_tau[2],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_tau[2],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_tau[2],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_tau[2],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 20Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
#ax.set_xlim([15., 25.0])
ax.set_xlim([35., 45.0])


plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/Tau-20Hz-Drive-PSD.eps'
#filenameeps = 'Figures/Tau-20Hz-Drive-PSD-zoom20.eps'
filenameeps = 'Figures/Tau-20Hz-Drive-PSD-zoom40.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### G Inh

# %% [markdown]
# ### MEG

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_g[0],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_g[0],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_g[0],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_g[0],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_g[0],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_g[0],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_g[0],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_g[0],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_g[0],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_g[0],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_g[0],str(colors[10]))

ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence (G condition) - 40Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/G-40Hz-Drive-MEG.eps'
filenameeps = 'Figures/G-40Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_g[1],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_g[1],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_g[1],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_g[1],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_g[1],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_g[1],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_g[1],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_g[1],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_g[1],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_g[1],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_g[1],str(colors[10]))

ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence (G condition) - 30Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


filenameeps = 'Figures/G-30Hz-Drive-MEG.eps'
#filenameeps = 'Figures/G-30Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_g[2],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_g[2],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_g[2],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_g[2],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_g[2],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_g[2],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_g[2],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_g[2],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_g[2],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_g[2],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_g[2],str(colors[10]))

ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence (G condition) - 20Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


filenameeps = 'Figures/G-20Hz-Drive-MEG.eps'
#filenameeps = 'Figures/G-20Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### PSD

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_g[0],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_g[0],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_g[0],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_g[0],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_g[0],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_g[0],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_g[0],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_g[0],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_g[0],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_g[0],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_g[0],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 40Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
#ax.set_xlim([35., 45.0])
ax.set_xlim([15., 25.0])


ax.set_ylim([0., 25.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/G-40Hz-Drive-PSD.eps'
#filenameeps = 'Figures/G-40Hz-Drive-PSD-zoom40.eps'
filenameeps = 'Figures/G-40Hz-Drive-PSD-zoom20.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_g[1],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_g[1],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_g[1],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_g[1],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_g[1],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_g[1],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_g[1],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_g[1],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_g[1],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_g[1],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_g[1],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 30Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
ax.set_xlim([25., 35.0])


plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/G-30Hz-Drive-PSD.eps'
filenameeps = 'Figures/G-30Hz-Drive-PSD-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_g[2],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_g[2],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_g[2],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_g[2],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_g[2],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_g[2],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_g[2],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_g[2],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_g[2],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_g[2],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_g[2],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 20Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
#ax.set_xlim([35., 45.0])
ax.set_xlim([15., 25.0])




plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/G-20Hz-Drive-PSD.eps'
#filenameeps = 'Figures/G-20Hz-Drive-PSD-zoom40.eps'
filenameeps = 'Figures/G-20Hz-Drive-PSD-zoom20.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### Tau and G inh condition

# %% [markdown]
# ### MEG

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_gtau[0],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_gtau[0],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_gtau[0],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_gtau[0],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_gtau[0],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_gtau[0],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_gtau[0],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_gtau[0],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_gtau[0],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_gtau[0],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_gtau[0],str(colors[10]))

ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence (G and Tau condition) - 40Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/G-Tau-40Hz-Drive-MEG.eps'
filenameeps = 'Figures/G-Tau-40Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_gtau[1],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_gtau[1],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_gtau[1],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_gtau[1],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_gtau[1],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_gtau[1],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_gtau[1],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_gtau[1],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_gtau[1],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_gtau[1],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_gtau[1],str(colors[10]))

ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence (G and Tau condition) - 30Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/G-Tau-30Hz-Drive-MEG.eps'
filenameeps = 'Figures/G-Tau-30Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(time_points,meg_d01_gtau[2],str(colors[0]))
d02,=ax.plot(time_points,meg_d02_gtau[2],str(colors[1]))
d0225,=ax.plot(time_points,meg_d0225_gtau[2],str(colors[2]))
d025,=ax.plot(time_points,meg_d025_gtau[2],str(colors[3]))
d0275,=ax.plot(time_points,meg_d0275_gtau[2],str(colors[4]))
d03,=ax.plot(time_points,meg_d03_gtau[2],str(colors[5]))
d0325,=ax.plot(time_points,meg_d0325_gtau[2],str(colors[6]))
d035,=ax.plot(time_points,meg_d035_gtau[2],str(colors[7]))
d0375,=ax.plot(time_points,meg_d0375_gtau[2],str(colors[8]))
d04,=ax.plot(time_points,meg_d04_gtau[2],str(colors[9]))
d05,=ax.plot(time_points,meg_d05_gtau[2],str(colors[10]))

ax.set_xlabel('Time (ms)',fontsize=36.0)
ax.set_ylabel('MEG (mV)',fontsize=36.0)
ax.set_title('Input Strength Dependence (G and Tau condition) - 20Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
ax.set_xlim([0., 100.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/G-Tau-20Hz-Drive-MEG.eps'
filenameeps = 'Figures/G-Tau-20Hz-Drive-MEG-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### PSD

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_gtau[0],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_gtau[0],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_gtau[0],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_gtau[0],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_gtau[0],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_gtau[0],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_gtau[0],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_gtau[0],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_gtau[0],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_gtau[0],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_gtau[0],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 40Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
#ax.set_xlim([35., 45.0])
ax.set_xlim([15., 25.0])


ax.set_ylim([0., 25.0])

plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/G-Tau-40Hz-Drive-PSD.eps'
#filenameeps = 'Figures/G-Tau-40Hz-Drive-PSD-zoom40.eps'
filenameeps = 'Figures/G-Tau-40Hz-Drive-PSD-zoom20.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_gtau[1],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_gtau[1],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_gtau[1],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_gtau[1],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_gtau[1],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_gtau[1],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_gtau[1],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_gtau[1],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_gtau[1],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_gtau[1],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_gtau[1],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 30Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
ax.set_xlim([25., 35.0])


plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/G-Tau-30Hz-Drive-PSD.eps'
filenameeps = 'Figures/G-Tau-30Hz-Drive-PSD-zoom.eps'
plt.savefig(filenameeps,dpi=600)

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

colors = np.linspace(0.75,0.0,11)

d01,=ax.plot(freqs*1000,psd_d01_gtau[2],str(colors[0]))
d02,=ax.plot(freqs*1000,psd_d02_gtau[2],str(colors[1]))
d0225,=ax.plot(freqs*1000,psd_d0225_gtau[2],str(colors[2]))
d025,=ax.plot(freqs*1000,psd_d025_gtau[2],str(colors[3]))
d0275,=ax.plot(freqs*1000,psd_d0275_gtau[2],str(colors[4]))
d03,=ax.plot(freqs*1000,psd_d03_gtau[2],str(colors[5]))
d0325,=ax.plot(freqs*1000,psd_d0325_gtau[2],str(colors[6]))
d035,=ax.plot(freqs*1000,psd_d035_gtau[2],str(colors[7]))
d0375,=ax.plot(freqs*1000,psd_d0375_gtau[2],str(colors[8]))
d04,=ax.plot(freqs*1000,psd_d04_gtau[2],str(colors[9]))
d05,=ax.plot(freqs*1000,psd_d05_gtau[2],str(colors[10]))

ax.set_xlabel('Frequency (Hz)',fontsize=36.0)
ax.set_ylabel('PSD (au)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 20Hz Drive',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)
#ax.set_xlim([0., 50.0])
#ax.set_xlim([15., 25.0])
ax.set_xlim([35., 45.0])


plt.legend([d01,d02,d0225,d025,d0275,d03,d0325,d035,d0375,d04,d05], 
           ['d01','d02','d0225','d025','d0275','d03','d0325','d035','d0375','d04','d05'])


#filenameeps = 'Figures/G-Tau-20Hz-Drive-PSD.eps'
#filenameeps = 'Figures/G-Tau-20Hz-Drive-PSD-zoom20.eps'
filenameeps = 'Figures/G-Tau-20Hz-Drive-PSD-zoom40.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ## Dependence on Input Strength

# %% [markdown]
# ### Extract Measures

# %%
# Control
d01_ctrl4040 =  np.sum(psd_d01_ctrl[0][19:22])
d02_ctrl4040 =  np.sum(psd_d02_ctrl[0][19:22])
d0225_ctrl4040 =  np.sum(psd_d0225_ctrl[0][19:22])
d025_ctrl4040 =  np.sum(psd_d025_ctrl[0][19:22])
d0275_ctrl4040 =  np.sum(psd_d0275_ctrl[0][19:22])
d03_ctrl4040 =  np.sum(psd_d03_ctrl[0][19:22])
d0325_ctrl4040 =  np.sum(psd_d0325_ctrl[0][19:22])
d035_ctrl4040 =  np.sum(psd_d035_ctrl[0][19:22])
d0375_ctrl4040 =  np.sum(psd_d0375_ctrl[0][19:22])
d04_ctrl4040 =  np.sum(psd_d04_ctrl[0][19:22])
d05_ctrl4040 =  np.sum(psd_d05_ctrl[0][19:22])

d01_ctrl2040 =  np.sum(psd_d01_ctrl[0][9:12])
d02_ctrl2040 =  np.sum(psd_d02_ctrl[0][9:12])
d0225_ctrl2040 =  np.sum(psd_d0225_ctrl[0][9:12])
d025_ctrl2040 =  np.sum(psd_d025_ctrl[0][9:12])
d0275_ctrl2040 =  np.sum(psd_d0275_ctrl[0][9:12])
d03_ctrl2040 =  np.sum(psd_d03_ctrl[0][9:12])
d0325_ctrl2040 =  np.sum(psd_d0325_ctrl[0][9:12])
d035_ctrl2040 =  np.sum(psd_d035_ctrl[0][9:12])
d0375_ctrl2040 =  np.sum(psd_d0375_ctrl[0][9:12])
d04_ctrl2040 =  np.sum(psd_d04_ctrl[0][9:12])
d05_ctrl2040 =  np.sum(psd_d05_ctrl[0][9:12])

d01_ctrl3030 =  np.sum(psd_d01_ctrl[1][14:16])
d02_ctrl3030 =  np.sum(psd_d02_ctrl[1][14:16])
d0225_ctrl3030 =  np.sum(psd_d0225_ctrl[1][14:16])
d025_ctrl3030 =  np.sum(psd_d025_ctrl[1][14:16])
d0275_ctrl3030 =  np.sum(psd_d0275_ctrl[1][14:16])
d03_ctrl3030 =  np.sum(psd_d03_ctrl[1][14:16])
d0325_ctrl3030 =  np.sum(psd_d0325_ctrl[1][14:16])
d035_ctrl3030 =  np.sum(psd_d035_ctrl[1][14:16])
d0375_ctrl3030 =  np.sum(psd_d0375_ctrl[1][14:16])
d04_ctrl3030 =  np.sum(psd_d04_ctrl[1][14:16])
d05_ctrl3030 =  np.sum(psd_d05_ctrl[1][14:16])

d01_ctrl4020 =  np.sum(psd_d01_ctrl[2][19:22])
d02_ctrl4020 =  np.sum(psd_d02_ctrl[2][19:22])
d0225_ctrl4020 =  np.sum(psd_d0225_ctrl[2][19:22])
d025_ctrl4020 =  np.sum(psd_d025_ctrl[2][19:22])
d0275_ctrl4020 =  np.sum(psd_d0275_ctrl[2][19:22])
d03_ctrl4020 =  np.sum(psd_d03_ctrl[2][19:22])
d0325_ctrl4020 =  np.sum(psd_d0325_ctrl[2][19:22])
d035_ctrl4020 =  np.sum(psd_d035_ctrl[2][19:22])
d0375_ctrl4020 =  np.sum(psd_d0375_ctrl[2][19:22])
d04_ctrl4020 =  np.sum(psd_d04_ctrl[2][19:22])
d05_ctrl4020 =  np.sum(psd_d05_ctrl[2][19:22])

d01_ctrl2020 =  np.sum(psd_d01_ctrl[2][9:12])
d02_ctrl2020 =  np.sum(psd_d02_ctrl[2][9:12])
d0225_ctrl2020 =  np.sum(psd_d0225_ctrl[2][9:12])
d025_ctrl2020 =  np.sum(psd_d025_ctrl[2][9:12])
d0275_ctrl2020 =  np.sum(psd_d0275_ctrl[2][9:12])
d03_ctrl2020 =  np.sum(psd_d03_ctrl[2][9:12])
d0325_ctrl2020 =  np.sum(psd_d0325_ctrl[2][9:12])
d035_ctrl2020 =  np.sum(psd_d035_ctrl[2][9:12])
d0375_ctrl2020 =  np.sum(psd_d0375_ctrl[2][9:12])
d04_ctrl2020 =  np.sum(psd_d04_ctrl[2][9:12])
d05_ctrl2020 =  np.sum(psd_d05_ctrl[2][9:12])

# Tau Inh
d01_tau4040 =  np.sum(psd_d01_tau[0][19:22])
d02_tau4040 =  np.sum(psd_d02_tau[0][19:22])
d0225_tau4040 =  np.sum(psd_d0225_tau[0][19:22])
d025_tau4040 =  np.sum(psd_d025_tau[0][19:22])
d0275_tau4040 =  np.sum(psd_d0275_tau[0][19:22])
d03_tau4040 =  np.sum(psd_d03_tau[0][19:22])
d0325_tau4040 =  np.sum(psd_d0325_tau[0][19:22])
d035_tau4040 =  np.sum(psd_d035_tau[0][19:22])
d0375_tau4040 =  np.sum(psd_d0375_tau[0][19:22])
d04_tau4040 =  np.sum(psd_d04_tau[0][19:22])
d05_tau4040 =  np.sum(psd_d05_tau[0][19:22])

d01_tau2040 =  np.sum(psd_d01_tau[0][9:12])
d02_tau2040 =  np.sum(psd_d02_tau[0][9:12])
d0225_tau2040 =  np.sum(psd_d0225_tau[0][9:12])
d025_tau2040 =  np.sum(psd_d025_tau[0][9:12])
d0275_tau2040 =  np.sum(psd_d0275_tau[0][9:12])
d03_tau2040 =  np.sum(psd_d03_tau[0][9:12])
d0325_tau2040 =  np.sum(psd_d0325_tau[0][9:12])
d035_tau2040 =  np.sum(psd_d035_tau[0][9:12])
d0375_tau2040 =  np.sum(psd_d0375_tau[0][9:12])
d04_tau2040 =  np.sum(psd_d04_tau[0][9:12])
d05_tau2040 =  np.sum(psd_d05_tau[0][9:12])

d01_tau3030 =  np.sum(psd_d01_tau[1][14:16])
d02_tau3030 =  np.sum(psd_d02_tau[1][14:16])
d0225_tau3030 =  np.sum(psd_d0225_tau[1][14:16])
d025_tau3030 =  np.sum(psd_d025_tau[1][14:16])
d0275_tau3030 =  np.sum(psd_d0275_tau[1][14:16])
d03_tau3030 =  np.sum(psd_d03_tau[1][14:16])
d0325_tau3030 =  np.sum(psd_d0325_tau[1][14:16])
d035_tau3030 =  np.sum(psd_d035_tau[1][14:16])
d0375_tau3030 =  np.sum(psd_d0375_tau[1][14:16])
d04_tau3030 =  np.sum(psd_d04_tau[1][14:16])
d05_tau3030 =  np.sum(psd_d05_tau[1][14:16])

d01_tau4020 =  np.sum(psd_d01_tau[2][19:22])
d02_tau4020 =  np.sum(psd_d02_tau[2][19:22])
d0225_tau4020 =  np.sum(psd_d0225_tau[2][19:22])
d025_tau4020 =  np.sum(psd_d025_tau[2][19:22])
d0275_tau4020 =  np.sum(psd_d0275_tau[2][19:22])
d03_tau4020 =  np.sum(psd_d03_tau[2][19:22])
d0325_tau4020 =  np.sum(psd_d0325_tau[2][19:22])
d035_tau4020 =  np.sum(psd_d035_tau[2][19:22])
d0375_tau4020 =  np.sum(psd_d0375_tau[2][19:22])
d04_tau4020 =  np.sum(psd_d04_tau[2][19:22])
d05_tau4020 =  np.sum(psd_d05_tau[2][19:22])

d01_tau2020 =  np.sum(psd_d01_tau[2][9:12])
d02_tau2020 =  np.sum(psd_d02_tau[2][9:12])
d0225_tau2020 =  np.sum(psd_d0225_tau[2][9:12])
d025_tau2020 =  np.sum(psd_d025_tau[2][9:12])
d0275_tau2020 =  np.sum(psd_d0275_tau[2][9:12])
d03_tau2020 =  np.sum(psd_d03_tau[2][9:12])
d0325_tau2020 =  np.sum(psd_d0325_tau[2][9:12])
d035_tau2020 =  np.sum(psd_d035_tau[2][9:12])
d0375_tau2020 =  np.sum(psd_d0375_tau[2][9:12])
d04_tau2020 =  np.sum(psd_d04_tau[2][9:12])
d05_tau2020 =  np.sum(psd_d05_tau[2][9:12])

# G Inh

d01_g4040 =  np.sum(psd_d01_g[0][19:22])
d02_g4040 =  np.sum(psd_d02_g[0][19:22])
d0225_g4040 =  np.sum(psd_d0225_g[0][19:22])
d025_g4040 =  np.sum(psd_d025_g[0][19:22])
d0275_g4040 =  np.sum(psd_d0275_g[0][19:22])
d03_g4040 =  np.sum(psd_d03_g[0][19:22])
d0325_g4040 =  np.sum(psd_d0325_g[0][19:22])
d035_g4040 =  np.sum(psd_d035_g[0][19:22])
d0375_g4040 =  np.sum(psd_d0375_g[0][19:22])
d04_g4040 =  np.sum(psd_d04_g[0][19:22])
d05_g4040 =  np.sum(psd_d05_g[0][19:22])

d01_g2040 =  np.sum(psd_d01_g[0][9:12])
d02_g2040 =  np.sum(psd_d02_g[0][9:12])
d0225_g2040 =  np.sum(psd_d0225_g[0][9:12])
d025_g2040 =  np.sum(psd_d025_g[0][9:12])
d0275_g2040 =  np.sum(psd_d0275_g[0][9:12])
d03_g2040 =  np.sum(psd_d03_g[0][9:12])
d0325_g2040 =  np.sum(psd_d0325_g[0][9:12])
d035_g2040 =  np.sum(psd_d035_g[0][9:12])
d0375_g2040 =  np.sum(psd_d0375_g[0][9:12])
d04_g2040 =  np.sum(psd_d04_g[0][9:12])
d05_g2040 =  np.sum(psd_d05_g[0][9:12])

d01_g3030 =  np.sum(psd_d01_g[1][14:16])
d02_g3030 =  np.sum(psd_d02_g[1][14:16])
d0225_g3030 =  np.sum(psd_d0225_g[1][14:16])
d025_g3030 =  np.sum(psd_d025_g[1][14:16])
d0275_g3030 =  np.sum(psd_d0275_g[1][14:16])
d03_g3030 =  np.sum(psd_d03_g[1][14:16])
d0325_g3030 =  np.sum(psd_d0325_g[1][14:16])
d035_g3030 =  np.sum(psd_d035_g[1][14:16])
d0375_g3030 =  np.sum(psd_d0375_g[1][14:16])
d04_g3030 =  np.sum(psd_d04_g[1][14:16])
d05_g3030 =  np.sum(psd_d05_g[1][14:16])

d01_g4020 =  np.sum(psd_d01_g[2][19:22])
d02_g4020 =  np.sum(psd_d02_g[2][19:22])
d0225_g4020 =  np.sum(psd_d0225_g[2][19:22])
d025_g4020 =  np.sum(psd_d025_g[2][19:22])
d0275_g4020 =  np.sum(psd_d0275_g[2][19:22])
d03_g4020 =  np.sum(psd_d03_g[2][19:22])
d0325_g4020 =  np.sum(psd_d0325_g[2][19:22])
d035_g4020 =  np.sum(psd_d035_g[2][19:22])
d0375_g4020 =  np.sum(psd_d0375_g[2][19:22])
d04_g4020 =  np.sum(psd_d04_g[2][19:22])
d05_g4020 =  np.sum(psd_d05_g[2][19:22])

d01_g2020 =  np.sum(psd_d01_g[2][9:12])
d02_g2020 =  np.sum(psd_d02_g[2][9:12])
d0225_g2020 =  np.sum(psd_d0225_g[2][9:12])
d025_g2020 =  np.sum(psd_d025_g[2][9:12])
d0275_g2020 =  np.sum(psd_d0275_g[2][9:12])
d03_g2020 =  np.sum(psd_d03_g[2][9:12])
d0325_g2020 =  np.sum(psd_d0325_g[2][9:12])
d035_g2020 =  np.sum(psd_d035_g[2][9:12])
d0375_g2020 =  np.sum(psd_d0375_g[2][9:12])
d04_g2020 =  np.sum(psd_d04_g[2][9:12])
d05_g2020 =  np.sum(psd_d05_g[2][9:12])

# G and Tau Inh

d01_gtau4040 =  np.sum(psd_d01_gtau[0][19:22])
d02_gtau4040 =  np.sum(psd_d02_gtau[0][19:22])
d0225_gtau4040 =  np.sum(psd_d0225_gtau[0][19:22])
d025_gtau4040 =  np.sum(psd_d025_gtau[0][19:22])
d0275_gtau4040 =  np.sum(psd_d0275_gtau[0][19:22])
d03_gtau4040 =  np.sum(psd_d03_gtau[0][19:22])
d0325_gtau4040 =  np.sum(psd_d0325_gtau[0][19:22])
d035_gtau4040 =  np.sum(psd_d035_gtau[0][19:22])
d0375_gtau4040 =  np.sum(psd_d0375_gtau[0][19:22])
d04_gtau4040 =  np.sum(psd_d04_gtau[0][19:22])
d05_gtau4040 =  np.sum(psd_d05_gtau[0][19:22])

d01_gtau2040 =  np.sum(psd_d01_gtau[0][9:12])
d02_gtau2040 =  np.sum(psd_d02_gtau[0][9:12])
d0225_gtau2040 =  np.sum(psd_d0225_gtau[0][9:12])
d025_gtau2040 =  np.sum(psd_d025_gtau[0][9:12])
d0275_gtau2040 =  np.sum(psd_d0275_gtau[0][9:12])
d03_gtau2040 =  np.sum(psd_d03_gtau[0][9:12])
d0325_gtau2040 =  np.sum(psd_d0325_gtau[0][9:12])
d035_gtau2040 =  np.sum(psd_d035_gtau[0][9:12])
d0375_gtau2040 =  np.sum(psd_d0375_gtau[0][9:12])
d04_gtau2040 =  np.sum(psd_d04_gtau[0][9:12])
d05_gtau2040 =  np.sum(psd_d05_gtau[0][9:12])

d01_gtau3030 =  np.sum(psd_d01_gtau[1][14:16])
d02_gtau3030 =  np.sum(psd_d02_gtau[1][14:16])
d0225_gtau3030 =  np.sum(psd_d0225_gtau[1][14:16])
d025_gtau3030 =  np.sum(psd_d025_gtau[1][14:16])
d0275_gtau3030 =  np.sum(psd_d0275_gtau[1][14:16])
d03_gtau3030 =  np.sum(psd_d03_gtau[1][14:16])
d0325_gtau3030 =  np.sum(psd_d0325_gtau[1][14:16])
d035_gtau3030 =  np.sum(psd_d035_gtau[1][14:16])
d0375_gtau3030 =  np.sum(psd_d0375_gtau[1][14:16])
d04_gtau3030 =  np.sum(psd_d04_gtau[1][14:16])
d05_gtau3030 =  np.sum(psd_d05_gtau[1][14:16])

d01_gtau4020 =  np.sum(psd_d01_gtau[2][19:22])
d02_gtau4020 =  np.sum(psd_d02_gtau[2][19:22])
d0225_gtau4020 =  np.sum(psd_d0225_gtau[2][19:22])
d025_gtau4020 =  np.sum(psd_d025_gtau[2][19:22])
d0275_gtau4020 =  np.sum(psd_d0275_gtau[2][19:22])
d03_gtau4020 =  np.sum(psd_d03_gtau[2][19:22])
d0325_gtau4020 =  np.sum(psd_d0325_gtau[2][19:22])
d035_gtau4020 =  np.sum(psd_d035_gtau[2][19:22])
d0375_gtau4020 =  np.sum(psd_d0375_gtau[2][19:22])
d04_gtau4020 =  np.sum(psd_d04_gtau[2][19:22])
d05_gtau4020 =  np.sum(psd_d05_gtau[2][19:22])

d01_gtau2020 =  np.sum(psd_d01_gtau[2][9:12])
d02_gtau2020 =  np.sum(psd_d02_gtau[2][9:12])
d0225_gtau2020 =  np.sum(psd_d0225_gtau[2][9:12])
d025_gtau2020 =  np.sum(psd_d025_gtau[2][9:12])
d0275_gtau2020 =  np.sum(psd_d0275_gtau[2][9:12])
d03_gtau2020 =  np.sum(psd_d03_gtau[2][9:12])
d0325_gtau2020 =  np.sum(psd_d0325_gtau[2][9:12])
d035_gtau2020 =  np.sum(psd_d035_gtau[2][9:12])
d0375_gtau2020 =  np.sum(psd_d0375_gtau[2][9:12])
d04_gtau2020 =  np.sum(psd_d04_gtau[2][9:12])
d05_gtau2020 =  np.sum(psd_d05_gtau[2][9:12])

# %% [markdown]
# ### 4040 Measure

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

g_de = [0.1, 0.2, 0.225, 0.25, 0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.5]
ctrl4040 = [d01_ctrl4040, d02_ctrl4040, d0225_ctrl4040, d025_ctrl4040, d0275_ctrl4040, d03_ctrl4040,
            d0325_ctrl4040, d035_ctrl4040, d0375_ctrl4040, d04_ctrl4040, d05_ctrl4040]
tau4040 = [d01_tau4040, d02_tau4040, d0225_tau4040, d025_tau4040, d0275_tau4040, d03_tau4040,
           d0325_tau4040, d035_tau4040, d0375_tau4040, d04_tau4040, d05_tau4040]
g4040 = [d01_g4040, d02_g4040, d0225_g4040, d025_g4040, d0275_g4040, d03_g4040,
         d0325_g4040, d035_g4040, d0375_g4040, d04_g4040, d05_g4040]
gtau4040 = [d01_gtau4040, d02_gtau4040, d0225_gtau4040, d025_gtau4040, d0275_gtau4040, d03_gtau4040,
            d0325_gtau4040, d035_gtau4040, d0375_gtau4040, d04_gtau4040, d05_gtau4040]

ctrl,=ax.plot(g_de,ctrl4040,'k*-')
tau,=ax.plot(g_de,tau4040,'r*-')
g,=ax.plot(g_de,g4040,'g*-')
gtau,=ax.plot(g_de,gtau4040,'b*-')


ax.set_xlabel('Input Strength',fontsize=36.0)
ax.set_ylabel('4040 Power (a.u.)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 4040 Measure',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)


plt.legend([ctrl,tau,g,gtau], 
           ['ctrl','tau','g','gtau'])

filenameeps = 'Figures/Measure4040.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### 2040 Measure

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

g_de = [0.1, 0.2, 0.225, 0.25, 0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.5]
ctrl2040 = [d01_ctrl2040, d02_ctrl2040, d0225_ctrl2040, d025_ctrl2040, d0275_ctrl2040, d03_ctrl2040,
            d0325_ctrl2040, d035_ctrl2040, d0375_ctrl2040, d04_ctrl2040, d05_ctrl2040]
tau2040 = [d01_tau2040, d02_tau2040, d0225_tau2040, d025_tau2040, d0275_tau2040, d03_tau2040,
           d0325_tau2040, d035_tau2040, d0375_tau2040, d04_tau2040, d05_tau2040]
g2040 = [d01_g2040, d02_g2040, d0225_g2040, d025_g2040, d0275_g2040, d03_g2040,
         d0325_g2040, d035_g2040, d0375_g2040, d04_g2040, d05_g2040]
gtau2040 = [d01_gtau2040, d02_gtau2040, d0225_gtau2040, d025_gtau2040, d0275_gtau2040, d03_gtau2040,
            d0325_gtau2040, d035_gtau2040, d0375_gtau2040, d04_gtau2040, d05_gtau2040]

ctrl,=ax.plot(g_de,ctrl2040,'k*-')
tau,=ax.plot(g_de,tau2040,'r*-')
g,=ax.plot(g_de,g2040,'g*-')
gtau,=ax.plot(g_de,gtau2040,'b*-')


ax.set_xlabel('Input Strength',fontsize=36.0)
ax.set_ylabel('2040 Power (a.u.)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 2040 Measure',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)

plt.legend([ctrl,tau,g,gtau], 
           ['ctrl','tau','g','gtau'])

filenameeps = 'Figures/Measure2040.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### 3030 Measure

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

g_de = [0.1, 0.2, 0.225, 0.25, 0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.5]
ctrl3030 = [d01_ctrl3030, d02_ctrl3030, d0225_ctrl3030, d025_ctrl3030, d0275_ctrl3030, d03_ctrl3030,
            d0325_ctrl3030, d035_ctrl3030, d0375_ctrl3030, d04_ctrl3030, d05_ctrl3030]
tau3030 = [d01_tau3030, d02_tau3030, d0225_tau3030, d025_tau3030, d0275_tau3030, d03_tau3030,
           d0325_tau3030, d035_tau3030, d0375_tau3030, d04_tau3030, d05_tau3030]
g3030 = [d01_g3030, d02_g3030, d0225_g3030, d025_g3030, d0275_g3030, d03_g3030,
          d0325_g3030,  d035_g3030,  d0375_g3030, d04_g3030, d05_g3030]
gtau3030 = [d01_gtau3030, d02_gtau3030, d0225_gtau3030, d025_gtau3030, d0275_gtau3030, d03_gtau3030,
            d0325_gtau3030, d035_gtau3030, d0375_gtau3030, d04_gtau3030, d05_gtau3030]

ctrl,=ax.plot(g_de,ctrl3030,'k*-')
tau,=ax.plot(g_de,tau3030,'r*-')
g,=ax.plot(g_de,g3030,'g*-')
gtau,=ax.plot(g_de,gtau3030,'b*-')


ax.set_xlabel('Input Strength',fontsize=36.0)
ax.set_ylabel('3030 Power (a.u.)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 3030 Measure',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)

plt.legend([ctrl,tau,g,gtau], 
           ['ctrl','tau','g','gtau'])

filenameeps = 'Figures/Measure3030.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### 2020 Measure

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

g_de = [0.1, 0.2, 0.225, 0.25, 0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.5]
ctrl2020 = [d01_ctrl2020, d02_ctrl2020, d0225_ctrl2020, d025_ctrl2020, d0275_ctrl2020, d03_ctrl2020,
            d0325_ctrl2020, d035_ctrl2020, d0375_ctrl2020, d04_ctrl2020, d05_ctrl2020]
tau2020 = [d01_tau2020, d02_tau2020, d0225_tau2020, d025_tau2020, d0275_tau2020, d03_tau2020,
           d0325_tau2020, d035_tau2020, d0375_tau2020, d04_tau2020, d05_tau2020]
g2020 = [d01_g2020, d02_g2020, d0225_g2020, d025_g2020, d0275_g2020, d03_g2020,
         d0325_g2020, d035_g2020, d0375_g2020, d04_g2020, d05_g2020]
gtau2020 = [d01_gtau2020, d02_gtau2020, d0225_gtau2020, d025_gtau2020, d0275_gtau2020, d03_gtau2020,
            d0325_gtau2020, d035_gtau2020, d0375_gtau2020, d04_gtau2020, d05_gtau2020]

ctrl,=ax.plot(g_de,ctrl2020,'k*-')
tau,=ax.plot(g_de,tau2020,'r*-')
g,=ax.plot(g_de,g2020,'g*-')
gtau,=ax.plot(g_de,gtau2020,'b*-')


ax.set_xlabel('Input Strength',fontsize=36.0)
ax.set_ylabel('2020 Power (a.u.)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 2020 Measure',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)


plt.legend([ctrl,tau,g,gtau], 
           ['ctrl','tau','g','gtau'])

filenameeps = 'Figures/Measure2020.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### 4020 Measure

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

g_de = [0.1, 0.2, 0.225, 0.25, 0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.5]
ctrl4020 = [d01_ctrl4020, d02_ctrl4020, d0225_ctrl4020, d025_ctrl4020, d0275_ctrl4020, d03_ctrl4020,
            d0325_ctrl4020, d035_ctrl4020, d0375_ctrl4020, d04_ctrl4020, d05_ctrl4020]
tau4020 = [d01_tau4020, d02_tau4020, d0225_tau4020, d025_tau4020, d0275_tau4020, d03_tau4020,
           d0325_tau4020, d035_tau4020, d0375_tau4020, d04_tau4020, d05_tau4020]
g4020 = [d01_g4020, d02_g4020, d0225_g4020, d025_g4020, d0275_g4020, d03_g4020,
         d0325_g4020, d035_g4020, d0375_g4020, d04_g4020, d05_g4020]
gtau4020 = [d01_gtau4020, d02_gtau4020, d0225_gtau4020, d025_gtau4020, d0275_gtau4020, d03_gtau4020,
            d0325_gtau4020, d035_gtau4020, d0375_gtau4020, d04_gtau4020, d05_gtau4020]

ctrl,=ax.plot(g_de,ctrl4020,'k*-')
tau,=ax.plot(g_de,tau4020,'r*-')
g,=ax.plot(g_de,g4020,'g*-')
gtau,=ax.plot(g_de,gtau4020,'b*-')


ax.set_xlabel('Input Strength',fontsize=36.0)
ax.set_ylabel('4020 Power (a.u.)',fontsize=36.0)
ax.set_title('Input Strength Dependence - 4020 Measure',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)

plt.legend([ctrl,tau,g,gtau], 
           ['ctrl','tau','g','gtau'])

filenameeps = 'Figures/Measure4020.eps'
plt.savefig(filenameeps,dpi=600)

# %% [markdown]
# ### 20Drive40/20 Ratio

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

g_de = [0.1, 0.2, 0.225, 0.25, 0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.5]
ctrl20drive4020 = [d01_ctrl4020/d01_ctrl2020, d02_ctrl4020/d02_ctrl2020, d0225_ctrl4020/d02_ctrl2020,
                   d025_ctrl4020/d02_ctrl2020, d0275_ctrl4020/d02_ctrl2020, d03_ctrl4020/d03_ctrl2020,
                   d0325_ctrl4020/d03_ctrl2020, d035_ctrl4020/d03_ctrl2020, d0375_ctrl4020/d03_ctrl2020,
                   d04_ctrl4020/d04_ctrl2020, d05_ctrl4020/d05_ctrl2020]
tau20drive4020 = [d01_tau4020/d01_tau2020, d02_tau4020/d02_tau2020, d0225_tau4020/d02_tau2020, 
                  d025_tau4020/d02_tau2020, d0275_tau4020/d02_tau2020, d03_tau4020/d03_tau2020, 
                  d0325_tau4020/d03_tau2020, d035_tau4020/d03_tau2020, d0375_tau4020/d03_tau2020,
                  d04_tau4020/d04_tau2020, d05_tau4020/d05_tau2020]
g20drive4020 = [d01_g4020/d01_g2020, d02_g4020/d02_g2020, d0225_g4020/d02_g2020, d025_g4020/d02_g2020,
                d0275_g4020/d02_g2020, d03_g4020/d03_g2020, d0325_g4020/d03_g2020, d035_g4020/d03_g2020,
                d0375_g4020/d03_g2020, d04_g4020/d04_g2020, d05_g4020/d05_g2020]
gtau20drive4020 = [d01_gtau4020/d01_gtau2020, d02_gtau4020/d02_gtau2020, d0225_gtau4020/d02_gtau2020,
                   d025_gtau4020/d02_gtau2020, d0275_gtau4020/d02_gtau2020, d03_gtau4020/d03_gtau2020,
                   d0325_gtau4020/d03_gtau2020, d035_gtau4020/d03_gtau2020, d0375_gtau4020/d03_gtau2020,
                   d04_gtau4020/d04_gtau2020, d05_gtau4020/d05_gtau2020]

ctrl,=ax.plot(g_de,ctrl20drive4020,'k*-')
tau,=ax.plot(g_de,tau20drive4020,'r*-')
g,=ax.plot(g_de,g20drive4020,'g*-')
gtau,=ax.plot(g_de,gtau20drive4020,'b*-')


ax.set_xlabel('Input Strength',fontsize=36.0)
ax.set_ylabel('20D4020 Ratio',fontsize=36.0)
ax.set_title('Input Strength Dependence - 20D4020 Ratio',fontsize=40.0)
ax.tick_params(axis='both',labelsize=32.0)


plt.legend([ctrl,tau,g,gtau], 
           ['ctrl','tau','g','gtau'])

filenameeps = 'Figures/20-Drive40-20-Ratio.eps'
plt.savefig(filenameeps,dpi=600)
